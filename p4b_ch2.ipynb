# %%
print('hello world')
# Out:
# hello world

# %%
print("She said, 'hello world'")
# Out:
# She said, 'hello world'

# %%
# this is a comminet, it will be ignored by your computer
print("comments are very useful!")
# Out:
# comments are very useful!

# %%
# print a friendly greeding 
print("Hello world")
# Out:
# Hello world

# %%
print(hello world)
# Out:
#   File "<ipython-input-4-6135c6da936c>", line 1
#     print(hello world)
#                     ^
# SyntaxError: invalid syntax

# %%
prin("Hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-919ef47b99be> in <module>
# ----> 1 prin("Hello world")
#
# NameError: name 'prin' is not defined

# %%
print("Hello
      world")
# Out:
#   File "<ipython-input-6-d255bf7a5e81>", line 1
#     print("Hello
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
print("Hello\nworld")
# Out:
# Hello
# world

# %%
# store a short DNA sequence in the variable my_dna
my_dna = "ATGCGTA"

# %%
# store a short DNA sequence in the variable my_dna
my_dna = "ATGCGTA"
# now print the DNA sequence
print(my_dna)
# Out:
# ATGCGTA

# %%
my_dna = "ATGCGTA"
print(my_dna)
# change the value of my_dna
my_dna = "TGGTCCA"
# Out:
# ATGCGTA

# %%
# store a short DNA sequence in the variable banana
banana = "ATGCGTA"
# now print the DNA sequence
print(banana)
# Out:
# ATGCGTA

# %%
my_file = "my_file.txt"

# %%
my_dna = "AATT" + "GGCC"
print(my_dna)
# Out:
# AATTGGCC

# %%
upstream = "AAA"
my_dna = upstream + "ATGC"
# my_dna is now "AAAATGC"

# %%
upstream = "AAA"
downstream = "GGG"
my_dna = upstream + downstream 
# my_dna is now "AAAATGCGGG"

# %%
print("Hello" + "" + "world")
# Out:
# Helloworld

# %%
# this line doesn't produce any output
len("ATGC")
# Out:
# 4

# %%
dna_length = len("AGCT")
print(dna_length)
# Out:
# 4

# %%
# store the DNA sequence in a variable
my_dna = "ATGCGAGT"
# calculate the length of the sequence and store it in a variable
dna_length = len(my_dna)
# print a message telling us the DNA sequence length
print("The length of the DNA sequence is " + dna_length)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f53bc5cdc844> in <module>
#       4 dna_length = len(my_dna)
#       5 # print a message telling us the DNA sequence length
# ----> 6 print("The length of the DNA sequence is " + dna_length)
#
# TypeError: can only concatenate str (not "int") to str

# %%
my_dna = "ATGCGAGT"
dna_length = len(my_dna)
print("The length of the DNA squence is " + str(dna_length))
# Out:
# The length of the DNA squence is 8

# %%
my_dna = "ATGC"
# print my_dna in lower case
print(my_dna.lower())
# Out:
# atgc

# %%
my_dna = "ATGC"
# print the variable
print("before: " + my_dna)
# run the lower method and store the result
lowercase_dna = my_dna.lower()
# print the variable again
print("after: " + my_dna)
# Out:
# before: ATGC
# after: ATGC

# %%
my_number = len("AGTC")
# my_number is 4
print(my_number.lower())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-c53a52e51ed2> in <module>
#       1 my_number = len("AGTC")
#       2 # my_number is 4
# ----> 3 print(my_number.lower())
#
# AttributeError: 'int' object has no attribute 'lower'

# %%
protein = "vlspadktnv"
# replace valine with tyrosine
print(protein.replace("v", "y"))
# we can replace more than one character
print(protein.replace("vls", "ymt"))
# the original variable is not affected
print(protein)
# Out:
# ylspadktny
# ymtpadktnv
# vlspadktnv

# %%
protein = "vlspadktnv"
# print positions three to five
print(protein[3:5])
# postions start at zero, not one
print(protein[0:6])
# if we use a stop position beyond the end, it's the same as using the end
print(protein[0:60])
# Out:
# pa
# vlspad
# vlspadktnv

# %%
protein = "vlspadktnv"
first_residue = protein[0]

# %%
protein = "vlspadktnv"
# count amino acid residues
valine_count = protein.count('v')
lsp_count = protein.count ('lsp')
tryptophan_count = protein.count('w')

# now print the counts
print("valines: " + str(valine_count))
print("lsp " + str(lsp_count))
print("tryptophans: " + str(tryptophan_count))
# Out:
# valines: 2
# lsp 1
# tryptophans: 0

# %%
protein = "vlspadktnv"
print(str(protein.find('p')))
print(str(protein.find('kt')))
print(str(protein.find('w')))
# Out:
# 3
# 6
# -1

# %%
my_dna.count(my_motif)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-2af9ec9592d7> in <module>
# ----> 1 my_dna.count(my_motif)
#
# NameError: name 'my_motif' is not defined

# %%
my_motif.count(my_dna)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b53e9194142a> in <module>
# ----> 1 my_motif.count(my_dna)
#
# NameError: name 'my_motif' is not defined
